# %% [markdown]
# Reading Dataset

# %%
#importing required packages
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
def read_data(file_name):
  data=pd.read_excel(file_name)
  dataFrame1_countries = data[['Country Name','Indicator Name','1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
       '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
       '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
       '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
       '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
       '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
       '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022']]
  dataFrame2_years = data[['Indicator Name','1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
       '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
       '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
       '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
       '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
       '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
       '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022']]
  dataFrame1_countries = pd.DataFrame(dataFrame1_countries)
  dataFrame2_years = pd.DataFrame(dataFrame2_years)
  return dataFrame1_countries, dataFrame2_years

# %%
#fetching xls file from drive

file_path =  "/content/drive/MyDrive/API_19_DS2_en_excel_v2_6224517.xls"
countries, years=read_data(file_path)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
countries
# Out:
#       Country Name                                     Indicator Name  \
# 0            Aruba           Urban population (% of total population)
# 1            Aruba                                   Urban population
# 2            Aruba                 Urban population growth (annual %)
# 3            Aruba                                  Population, total
# 4            Aruba                       Population growth (annual %)
# ...            ...                                                ...
# 20211     Zimbabwe  Rural land area where elevation is below 5 met...
# 20212     Zimbabwe  Rural land area where elevation is below 5 met...
# 20213     Zimbabwe                       Arable land (% of land area)
# 20214     Zimbabwe                 Agricultural land (% of land area)
# 20215     Zimbabwe                         Agricultural land (sq. km)
#
#             1960           1961           1962           1963           1964  \
# ...

# %%
unique_countries = countries['Country Name'].unique()
unique_indicators = countries['Indicator Name'].unique()

# Display the lists
print("List of Unique Country Names:")
print(unique_countries)

print("\nList of Unique Indicators:")
print(unique_indicators)
# Out:
# List of Unique Country Names:
# ['Aruba' 'Africa Eastern and Southern' 'Afghanistan'
#  'Africa Western and Central' 'Angola' 'Albania' 'Andorra' 'Arab World'
#  'United Arab Emirates' 'Argentina' 'Armenia' 'American Samoa'
#  'Antigua and Barbuda' 'Australia' 'Austria' 'Azerbaijan' 'Burundi'
#  'Belgium' 'Benin' 'Burkina Faso' 'Bangladesh' 'Bulgaria' 'Bahrain'
#  'Bahamas, The' 'Bosnia and Herzegovina' 'Belarus' 'Belize' 'Bermuda'
#  'Bolivia' 'Brazil' 'Barbados' 'Brunei Darussalam' 'Bhutan' 'Botswana'
#  'Central African Republic' 'Canada' 'Central Europe and the Baltics'
#  'Switzerland' 'Channel Islands' 'Chile' 'China' "Cote d'Ivoire"
#  'Cameroon' 'Congo, Dem. Rep.' 'Congo, Rep.' 'Colombia' 'Comoros'
#  'Cabo Verde' 'Costa Rica' 'Caribbean small states' 'Cuba' 'Curacao'
#  'Cayman Islands' 'Cyprus' 'Czechia' 'Germany' 'Djibouti' 'Dominica'
#  'Denmark' 'Dominican Republic' 'Algeria'
#  'East Asia & Pacific (excluding high income)'
# ...

# %%
selected_countries = ['United States', 'India', 'China']
selected_indicators = [
    'Urban population (% of total population)',
    'CO2 emissions (metric tons per capita)',
    'Cereal yield (kg per hectare)'
]


filtered_data = countries[
    (countries['Country Name'].isin(selected_countries)) &
    (countries['Indicator Name'].isin(selected_indicators))
]


for indicator in selected_indicators:
    indicator_data = filtered_data[filtered_data['Indicator Name'] == indicator]
    numeric_data = indicator_data.drop(['Country Name', 'Indicator Name'], axis=1)
    row_mean_values = numeric_data.mean(axis=1)
    row_std_dev_values = numeric_data.std(axis=1)


    print(f"=== Metrics Row-wise for {indicator} ===")
    print(f"Mean Values:")
    print(row_mean_values)
    print(f"\nStandard Deviation Values:")
    print(row_std_dev_values)
    print("\n" + "=" * 50 + "\n")
# Out:
# === Metrics Row-wise for Urban population (% of total population) ===
# Mean Values:
# 3040     32.313190
# 8284     25.865857
# 19076    76.680460
# dtype: float64
#
# Standard Deviation Values:
# 3040     15.277422
# 8284      5.141735
# 19076     3.769963
# dtype: float64
#
# ...
#
# === Metrics Row-wise for CO2 emissions (metric tons per capita) ===
# Mean Values:
# 3081      4.655473
# 8325      1.133496
# 19117    17.986275
# dtype: float64
#
# Standard Deviation Values:
# 3081     2.181781
# 8325     0.380304
# 19117    2.094321
# dtype: float64
#
# ...
#
# === Metrics Row-wise for Cereal yield (kg per hectare) ===
# Mean Values:
# 3103     4028.637705
# 8347     1946.675410
# 19139    5115.085246
# dtype: float64
#
# Standard Deviation Values:
# 3103     1547.719855
# 8347      768.229095
# 19139    1719.358098
# dtype: float64
#
# ...

# %%
selected_countries = ['United States', 'India', 'China']
selected_indicators = [
    'Urban population (% of total population)',
    'CO2 emissions (metric tons per capita)',
    'Cereal yield (kg per hectare)'
]


filtered_data = countries[
    (countries['Country Name'].isin(selected_countries)) &
    (countries['Indicator Name'].isin(selected_indicators))
]

for indicator in selected_indicators:
    indicator_data = filtered_data[filtered_data['Indicator Name'] == indicator]
    numeric_data = indicator_data.drop(['Country Name', 'Indicator Name'], axis=1)

    print(f"=== Describe for {indicator} ===")
    print(numeric_data.describe())
    print("\n" + "=" * 50 + "\n")
# Out:
# === Describe for Urban population (% of total population) ===
#             1960       1961       1962       1963      1964       1965  \
# count   3.000000   3.000000   3.000000   3.000000   3.00000   3.000000
# mean   34.707667  35.039000  35.400333  35.765333  36.13400  36.250000
# std    30.572705  30.610765  30.623789  30.631877  30.63514  30.857598
# min    16.203000  16.708000  17.226000  17.757000  18.29900  18.086000
# 25%    17.063500  17.370000  17.722000  18.081000  18.44700  18.435500
# 50%    17.924000  18.032000  18.218000  18.405000  18.59500  18.785000
# 75%    43.960000  44.204500  44.487500  44.769500  45.05150  45.332000
# max    69.996000  70.377000  70.757000  71.134000  71.50800  71.879000
#
#             1966       1967       1968       1969  ...       2013       2014  \
# count   3.000000   3.000000   3.000000   3.000000  ...   3.000000   3.000000
# mean   36.379667  36.522667  36.665333  36.807667  ...  55.438333  56.042000
# ...

# %%
selected_countries = ['United States', 'India', 'China']
selected_indicators = [
    'Urban population (% of total population)',
    'CO2 emissions (metric tons per capita)',
    'Cereal yield (kg per hectare)',
    'Population growth (annual %)',
    'Electricity production from renewable sources, excluding hydroelectric (% of total)',
]


filtered_data = countries[
    (countries['Country Name'].isin(selected_countries)) &
    (countries['Indicator Name'].isin(selected_indicators))
]


melted_data = pd.melt(filtered_data, id_vars=['Country Name', 'Indicator Name'], var_name='Year', value_name='Value')


melted_data['Year'] = pd.to_numeric(melted_data['Year'], errors='coerce')


correlation_matrix = melted_data.pivot_table(index='Country Name', columns='Indicator Name', values='Value', aggfunc='mean').corr()


plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=.5)
plt.title('Correlation Matrix of Selected Indicators')
plt.show()

# %%
years
# Out:
#                                           Indicator Name       1960  \
# 0               Urban population (% of total population)     50.776
# 1                                       Urban population  27728.000
# 2                     Urban population growth (annual %)        NaN
# 3                                      Population, total  54608.000
# 4                           Population growth (annual %)        NaN
# ...                                                  ...        ...
# 20211  Rural land area where elevation is below 5 met...        NaN
# 20212  Rural land area where elevation is below 5 met...        NaN
# 20213                       Arable land (% of land area)        NaN
# 20214                 Agricultural land (% of land area)        NaN
# 20215                         Agricultural land (sq. km)        NaN
#
#                 1961           1962           1963           1964  \
# 0          50.761000      50.746000      50.730000      50.715000
# ...

# %%
# Selecting specific countries and indicators
selected_countries = ['United States', 'India', 'China']
selected_indicators = [
    'Urban population (% of total population)',
    'CO2 emissions (metric tons per capita)',
    'Cereal yield (kg per hectare)',
    'Population growth (annual %)',
    'Electricity production from renewable sources, excluding hydroelectric (% of total)',
]

# Filter the dataset
filtered_data = countries[
    (countries['Country Name'].isin(selected_countries)) &
    (countries['Indicator Name'].isin(selected_indicators))
]

# Melt the dataset to have 'Year' as a column
melted_data = pd.melt(filtered_data, id_vars=['Country Name', 'Indicator Name'], var_name='Year', value_name='Value')

# Convert 'Year' to a numeric column
melted_data['Year'] = pd.to_numeric(melted_data['Year'], errors='coerce')

# Plot separate time series for each selected indicator
for indicator in selected_indicators:
    plt.figure(figsize=(12, 6))
    sns.set_palette("husl", len(selected_countries))
    for country in selected_countries:
        country_data = melted_data[(melted_data['Country Name'] == country) & (melted_data['Indicator Name'] == indicator)]
        plt.plot(country_data['Year'], country_data['Value'], label=f'{country}')

    plt.title(f'Time Series of {indicator} for Different Countries')
    plt.xlabel('Year')
    plt.ylabel('Value')
    plt.legend()
    plt.show()

# %%
from matplotlib import pyplot as plt
years['2005'].plot(kind='line', figsize=(8, 4), title='2005')
plt.gca().spines[['top', 'right']].set_visible(False)
